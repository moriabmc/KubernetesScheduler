# %%
import csv
import datetime
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_percentage_error as mape
import prophet

filePath = 'C:\\Users\\moria\\OneDrive\\Universität\\Bachelor\\Project\\KubernetesScheduler\\co2_prediction\\Germany_CO2_Signal_2018.csv'
savename = 'avg_co2_ger'
co2_emission_column = 3
unix_timestamp_column = 1

df = pd.DataFrame
a = 0
time = []
emission = []
timezone_unix_factor = 3600 # factor is necessary, as the unix timestamp is not standard compliant as timezone is set to UTC + 1
with open(filePath, 'r') as csvfile:
    lines = csv.reader(csvfile, delimiter=',')
    next(lines)  # skip the label field
    for row in lines:
        a = a + 1
        day = datetime.datetime.fromtimestamp(
            int(row[unix_timestamp_column]) - timezone_unix_factor)  # correction as timestamp is UTC not UTC + 1
        time.append(day)
        try:
            emission.append(float(row[co2_emission_column]))
        except:
            emission.append(None)
df = pd.DataFrame(list(zip(time, emission)), columns=['ds', 'y'])


df['ds'] = pd.to_datetime(df['ds'])

#df = df.set_index('ds') # Do not use for Prophet model
df = df.drop_duplicates(subset=['ds'])
#df = df.interpolate('ffill') # Do not use for Prophet model
print(df.isnull().any())

steps = 48
data_train = df[:-steps]
data_test  = df[-steps:]
# Out:
# ds    False
# y      True
# dtype: bool

# %%
m = prophet.Prophet()
m.fit(data_train)

future = m.make_future_dataframe(periods=steps, freq='H')
# Out:
# 10:52:27 - cmdstanpy - INFO - Chain [1] start processing
# 10:52:28 - cmdstanpy - INFO - Chain [1] done processing

# %%
forecast = m.predict(future)
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
#                       ds        yhat  yhat_lower  yhat_upper
# 8754 2018-12-31 19:00:00  380.475464  281.406442  487.592074
# 8755 2018-12-31 20:00:00  377.804352  274.174515  478.721522
# 8756 2018-12-31 21:00:00  372.943578  278.950823  472.788765
# 8757 2018-12-31 22:00:00  367.943827  259.848081  470.620661
# 8758 2018-12-31 23:00:00  362.860519  264.236457  470.112444

# %%
fig1 = m.plot(forecast)

# %%
    fig, ax = plt.subplots(figsize=(9, 4))
    data_train['y'][-steps*2:].plot(ax=ax, label='train')
    data_test['y'].plot(ax=ax, label='test')
    forecast['yhat'][-steps:].plot(ax=ax, label='yhat')
    forecast['yhat_lower'][-steps:].plot(ax=ax, label='yhat_lower')
    forecast['yhat_upper'][-steps:].plot(ax=ax, label='yhat_upper')
    ax.legend()

# %%
fig2 = m.plot_components(forecast)

# %%
error = mape(data_test['y'], forecast['yhat'][-steps:])
print(error)
# Out:
# 0.3258435454789183
